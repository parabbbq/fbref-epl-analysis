# %%
import pandas as pd
import numpy as np # We'll likely need numpy for NaN and other operations

# Load the raw dataset
try:
    df_raw = pd.read_csv('fbref_2024_2025_pl_standard_stats_raw.csv')
    print("Successfully loaded fbref_2024_2025_pl_standard_stats_raw.csv")
    print(f"Initial raw shape: {df_raw.shape}")
except FileNotFoundError:
    print("Error: fbref_2024_2025_pl_standard_stats_raw.csv not found. Make sure it's in the same directory as the notebook.")
    df_raw = pd.DataFrame() # Create an empty DataFrame to avoid further errors if file not found

# Display the first few rows and basic info to start
if not df_raw.empty:
    print("\nFirst 5 rows of raw data:")
    print(df_raw.head())
    print("\nInfo about raw data types and non-null values:")
    df_raw.info()
# Out:
# Successfully loaded fbref_2024_2025_pl_standard_stats_raw.csv
# Initial raw shape: (591, 37)
#
# First 5 rows of raw data:
#   Rk             Player   Nation    Pos        Squad     Age  Born  \
# 0  1         Max Aarons  eng ENG     DF  Bournemouth  25-132  2000
# 1  2  Joshua Acheampong  eng ENG     DF      Chelsea  19-011  2006
# 2  3        Tyler Adams   us USA     MF  Bournemouth  26-091  1999
# 3  4   Tosin Adarabioyo  eng ENG     DF      Chelsea  27-234  1997
# 4  5      Simon Adingra   ci CIV  FW,MF     Brighton  23-135  2002
#
#   Playing_Time_MP Playing_Time_Starts Playing_Time_Min  ...  \
# 0               3                   1               86  ...
# 1               4                   2              170  ...
# 2              26                  19             1785  ...
# 3              20                  13             1229  ...
# 4              27                  10              988  ...
#
#   Per_90_Minutes_Ast Per_90_Minutes_G+A Per_90_Minutes_G_PK  \
# 0               0.00               0.00                0.00
# 1               0.00               0.00                0.00
# 2               0.15               0.15                0.00
# 3               0.07               0.15                0.07
# 4               0.18               0.36                0.18
#
#   Per_90_Minutes_G+A_PK Per_90_Minutes_xG Per_90_Minutes_xAG  \
# 0                  0.00              0.00               0.00
# 1                  0.00              0.12               0.00
# 2                  0.15              0.08               0.05
# 3                  0.15              0.07               0.02
# 4                  0.36              0.20               0.21
#
#   Per_90_Minutes_xG+xAG Per_90_Minutes_npxG Per_90_Minutes_npxG+xAG  Matches
# 0                  0.00                0.00                    0.00  Matches
# 1                  0.12                0.12                    0.12  Matches
# 2                  0.13                0.08                    0.13  Matches
# 3                  0.08                0.07                    0.08  Matches
# 4                  0.42                0.20                    0.42  Matches
#
# [5 rows x 37 columns]
#
# Info about raw data types and non-null values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rk                       591 non-null    object
#  1   Player                   591 non-null    object
#  2   Nation                   588 non-null    object
#  3   Pos                      591 non-null    object
#  4   Squad                    591 non-null    object
#  5   Age                      588 non-null    object
#  6   Born                     588 non-null    object
#  7   Playing_Time_MP          591 non-null    object
#  8   Playing_Time_Starts      591 non-null    object
#  9   Playing_Time_Min         591 non-null    object
#  10  Playing_Time_90s         591 non-null    object
#  11  Performance_Gls          591 non-null    object
#  12  Performance_Ast          591 non-null    object
#  13  Performance_G+A          591 non-null    object
#  14  Performance_G_PK         591 non-null    object
#  15  Performance_PK           591 non-null    object
#  16  Performance_PKatt        591 non-null    object
#  17  Performance_CrdY         591 non-null    object
#  18  Performance_CrdR         591 non-null    object
#  19  Expected_xG              591 non-null    object
#  20  Expected_npxG            591 non-null    object
#  21  Expected_xAG             591 non-null    object
#  22  Expected_npxG+xAG        591 non-null    object
#  23  Progression_PrgC         591 non-null    object
#  24  Progression_PrgP         591 non-null    object
#  25  Progression_PrgR         591 non-null    object
#  26  Per_90_Minutes_Gls       591 non-null    object
#  27  Per_90_Minutes_Ast       591 non-null    object
#  28  Per_90_Minutes_G+A       591 non-null    object
#  29  Per_90_Minutes_G_PK      591 non-null    object
#  30  Per_90_Minutes_G+A_PK    591 non-null    object
#  31  Per_90_Minutes_xG        591 non-null    object
#  32  Per_90_Minutes_xAG       591 non-null    object
#  33  Per_90_Minutes_xG+xAG    591 non-null    object
#  34  Per_90_Minutes_npxG      591 non-null    object
#  35  Per_90_Minutes_npxG+xAG  591 non-null    object
#  36  Matches                  591 non-null    object
# dtypes: object(37)
# memory usage: 171.0+ KB

# %%
# Create a copy to work on
df = df_raw.copy()

# Identify rows that are likely headers
# A common characteristic of these header rows is that the 'Rk' column contains the string 'Rk'
# or another typically numeric column contains a non-numeric string that matches its header name.
header_row_mask = df['Rk'] == 'Rk' # Check where 'Rk' column has the string 'Rk'
num_header_rows = header_row_mask.sum()
print(f"Found {num_header_rows} potential repeated header rows based on 'Rk' column.")

# Display these potential header rows to confirm
if num_header_rows > 0:
    print("\nPotential header rows found:")
    print(df[header_row_mask])

# Remove these header rows
df = df[~header_row_mask] # Keep rows where the mask is False
print(f"\nShape after removing header rows: {df.shape}")

# Reset the index after dropping rows
df.reset_index(drop=True, inplace=True)

print("\nFirst 5 rows after removing headers:")
print(df.head())
print("\nLast 5 rows after removing headers:")
print(df.tail())
# Out:
# Found 22 potential repeated header rows based on 'Rk' column.
#
# Potential header rows found:
#      Rk  Player  Nation  Pos  Squad  Age  Born Playing_Time_MP  \
# 25   Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 51   Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 77   Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 103  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 129  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 155  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 181  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 207  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 233  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 259  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 285  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 311  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 337  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 363  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 389  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 415  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 441  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 467  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 493  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 519  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 545  Rk  Player  Nation  Pos  Squad  Age  Born              MP
# 571  Rk  Player  Nation  Pos  Squad  Age  Born              MP
#
#     Playing_Time_Starts Playing_Time_Min  ... Per_90_Minutes_Ast  \
# 25               Starts              Min  ...                Ast
# 51               Starts              Min  ...                Ast
# 77               Starts              Min  ...                Ast
# 103              Starts              Min  ...                Ast
# 129              Starts              Min  ...                Ast
# 155              Starts              Min  ...                Ast
# 181              Starts              Min  ...                Ast
# 207              Starts              Min  ...                Ast
# 233              Starts              Min  ...                Ast
# 259              Starts              Min  ...                Ast
# 285              Starts              Min  ...                Ast
# 311              Starts              Min  ...                Ast
# 337              Starts              Min  ...                Ast
# 363              Starts              Min  ...                Ast
# 389              Starts              Min  ...                Ast
# 415              Starts              Min  ...                Ast
# 441              Starts              Min  ...                Ast
# 467              Starts              Min  ...                Ast
# 493              Starts              Min  ...                Ast
# 519              Starts              Min  ...                Ast
# 545              Starts              Min  ...                Ast
# 571              Starts              Min  ...                Ast
#
#     Per_90_Minutes_G+A Per_90_Minutes_G_PK Per_90_Minutes_G+A_PK  \
# 25                 G+A                G-PK                G+A-PK
# 51                 G+A                G-PK                G+A-PK
# 77                 G+A                G-PK                G+A-PK
# 103                G+A                G-PK                G+A-PK
# 129                G+A                G-PK                G+A-PK
# 155                G+A                G-PK                G+A-PK
# 181                G+A                G-PK                G+A-PK
# 207                G+A                G-PK                G+A-PK
# 233                G+A                G-PK                G+A-PK
# 259                G+A                G-PK                G+A-PK
# 285                G+A                G-PK                G+A-PK
# 311                G+A                G-PK                G+A-PK
# 337                G+A                G-PK                G+A-PK
# 363                G+A                G-PK                G+A-PK
# 389                G+A                G-PK                G+A-PK
# 415                G+A                G-PK                G+A-PK
# 441                G+A                G-PK                G+A-PK
# 467                G+A                G-PK                G+A-PK
# 493                G+A                G-PK                G+A-PK
# 519                G+A                G-PK                G+A-PK
# 545                G+A                G-PK                G+A-PK
# 571                G+A                G-PK                G+A-PK
#
#     Per_90_Minutes_xG Per_90_Minutes_xAG Per_90_Minutes_xG+xAG  \
# 25                 xG                xAG                xG+xAG
# 51                 xG                xAG                xG+xAG
# 77                 xG                xAG                xG+xAG
# 103                xG                xAG                xG+xAG
# 129                xG                xAG                xG+xAG
# 155                xG                xAG                xG+xAG
# 181                xG                xAG                xG+xAG
# 207                xG                xAG                xG+xAG
# 233                xG                xAG                xG+xAG
# 259                xG                xAG                xG+xAG
# 285                xG                xAG                xG+xAG
# 311                xG                xAG                xG+xAG
# 337                xG                xAG                xG+xAG
# 363                xG                xAG                xG+xAG
# 389                xG                xAG                xG+xAG
# 415                xG                xAG                xG+xAG
# 441                xG                xAG                xG+xAG
# 467                xG                xAG                xG+xAG
# 493                xG                xAG                xG+xAG
# 519                xG                xAG                xG+xAG
# 545                xG                xAG                xG+xAG
# 571                xG                xAG                xG+xAG
#
#     Per_90_Minutes_npxG Per_90_Minutes_npxG+xAG  Matches
# 25                 npxG                npxG+xAG  Matches
# 51                 npxG                npxG+xAG  Matches
# 77                 npxG                npxG+xAG  Matches
# 103                npxG                npxG+xAG  Matches
# 129                npxG                npxG+xAG  Matches
# 155                npxG                npxG+xAG  Matches
# 181                npxG                npxG+xAG  Matches
# 207                npxG                npxG+xAG  Matches
# 233                npxG                npxG+xAG  Matches
# 259                npxG                npxG+xAG  Matches
# 285                npxG                npxG+xAG  Matches
# 311                npxG                npxG+xAG  Matches
# 337                npxG                npxG+xAG  Matches
# 363                npxG                npxG+xAG  Matches
# 389                npxG                npxG+xAG  Matches
# 415                npxG                npxG+xAG  Matches
# 441                npxG                npxG+xAG  Matches
# 467                npxG                npxG+xAG  Matches
# 493                npxG                npxG+xAG  Matches
# 519                npxG                npxG+xAG  Matches
# 545                npxG                npxG+xAG  Matches
# 571                npxG                npxG+xAG  Matches
#
# [22 rows x 37 columns]
#
# Shape after removing header rows: (569, 37)
#
# First 5 rows after removing headers:
#   Rk             Player   Nation    Pos        Squad     Age  Born  \
# 0  1         Max Aarons  eng ENG     DF  Bournemouth  25-132  2000
# 1  2  Joshua Acheampong  eng ENG     DF      Chelsea  19-011  2006
# 2  3        Tyler Adams   us USA     MF  Bournemouth  26-091  1999
# 3  4   Tosin Adarabioyo  eng ENG     DF      Chelsea  27-234  1997
# 4  5      Simon Adingra   ci CIV  FW,MF     Brighton  23-135  2002
#
#   Playing_Time_MP Playing_Time_Starts Playing_Time_Min  ...  \
# 0               3                   1               86  ...
# 1               4                   2              170  ...
# 2              26                  19             1785  ...
# 3              20                  13             1229  ...
# 4              27                  10              988  ...
#
#   Per_90_Minutes_Ast Per_90_Minutes_G+A Per_90_Minutes_G_PK  \
# 0               0.00               0.00                0.00
# 1               0.00               0.00                0.00
# 2               0.15               0.15                0.00
# 3               0.07               0.15                0.07
# 4               0.18               0.36                0.18
#
#   Per_90_Minutes_G+A_PK Per_90_Minutes_xG Per_90_Minutes_xAG  \
# 0                  0.00              0.00               0.00
# 1                  0.00              0.12               0.00
# 2                  0.15              0.08               0.05
# 3                  0.15              0.07               0.02
# 4                  0.36              0.20               0.21
#
#   Per_90_Minutes_xG+xAG Per_90_Minutes_npxG Per_90_Minutes_npxG+xAG  Matches
# 0                  0.00                0.00                    0.00  Matches
# 1                  0.12                0.12                    0.12  Matches
# 2                  0.13                0.08                    0.13  Matches
# 3                  0.08                0.07                    0.08  Matches
# 4                  0.42                0.20                    0.42  Matches
#
# [5 rows x 37 columns]
#
# Last 5 rows after removing headers:
#       Rk               Player   Nation    Pos           Squad     Age  Born  \
# 564  565         Ashley Young  eng ENG  DF,FW         Everton  39-311  1985
# 565  566       Illia Zabarnyi   ua UKR     DF     Bournemouth  22-257  2002
# 566  567  Oleksandr Zinchenko   ua UKR  DF,MF         Arsenal  28-152  1996
# 567  568       Joshua Zirkzee   nl NED  FW,MF  Manchester Utd  23-359  2001
# 568  569      Martin Ødegaard   no NOR     MF         Arsenal  26-150  1998
#
#     Playing_Time_MP Playing_Time_Starts Playing_Time_Min  ...  \
# 564              30                  18             1712  ...
# 565              34                  33             2929  ...
# 566              14                   4              458  ...
# 567              32                  14             1402  ...
# 568              28                  25             2220  ...
#
#     Per_90_Minutes_Ast Per_90_Minutes_G+A Per_90_Minutes_G_PK  \
# 564               0.16               0.21                0.05
# 565               0.00               0.00                0.00
# 566               0.20               0.20                0.00
# 567               0.06               0.26                0.19
# 568               0.28               0.36                0.04
#
#     Per_90_Minutes_G+A_PK Per_90_Minutes_xG Per_90_Minutes_xAG  \
# 564                  0.21              0.01               0.11
# 565                  0.00              0.03               0.02
# 566                  0.20              0.05               0.03
# 567                  0.26              0.31               0.10
# 568                  0.32              0.19               0.21
#
#     Per_90_Minutes_xG+xAG Per_90_Minutes_npxG Per_90_Minutes_npxG+xAG  Matches
# 564                  0.12                0.01                    0.12  Matches
# 565                  0.05                0.03                    0.05  Matches
# 566                  0.08                0.05                    0.08  Matches
# 567                  0.41                0.31                    0.41  Matches
# 568                  0.41                0.16                    0.37  Matches
#
# [5 rows x 37 columns]

# %%
# Investigate the 'Matches' column
print("Unique values in 'Matches' column and their counts:")
print(df['Matches'].value_counts(dropna=False)) # dropna=False will also show NaN counts if any

# If it's always 'Matches' or mostly 'Matches' and some NaNs, it's probably safe to drop.
# Let's assume for now it's not useful. We can decide to drop it later.
# Out:
# Unique values in 'Matches' column and their counts:
# Matches
# Matches    569
# Name: count, dtype: int64

# %%
# Clean the 'Age' column to extract only the age in years
# The lambda function splits the string by '-' and takes the first part (the age)
# We'll convert to numeric later, after handling potential NaNs more broadly
df['Age_Clean'] = df['Age'].astype(str).apply(lambda x: x.split('-')[0] if pd.notnull(x) and '-' in x else x)

print("\n'Age' column before and after cleaning (first 5 rows):")
print(df[['Age', 'Age_Clean']].head())

# We can drop the original 'Age' column later if we're happy with 'Age_Clean'
# Out:
# 'Age' column before and after cleaning (first 5 rows):
#       Age Age_Clean
# 0  25-132        25
# 1  19-011        19
# 2  26-091        26
# 3  27-234        27
# 4  23-135        23

# %%
# List of columns that should be numeric
# Based on your column list and typical FBref data:
# 'Rk', 'Born', 'Playing_Time_MP', 'Playing_Time_Starts', 'Playing_Time_Min', 
# 'Playing_Time_90s', 'Performance_Gls', 'Performance_Ast', 'Performance_G+A', 
# 'Performance_G_PK', 'Performance_PK', 'Performance_PKatt', 'Performance_CrdY', 
# 'Performance_CrdR', 'Expected_xG', 'Expected_npxG', 'Expected_xAG', 
# 'Expected_npxG+xAG', 'Progression_PrgC', 'Progression_PrgP', 'Progression_PrgR',
# 'Per_90_Minutes_Gls', 'Per_90_Minutes_Ast', 'Per_90_Minutes_G+A', 
# 'Per_90_Minutes_G_PK', 'Per_90_Minutes_G+A_PK', 'Per_90_Minutes_xG', 
# 'Per_90_Minutes_xAG', 'Per_90_Minutes_xG+xAG', 'Per_90_Minutes_npxG', 
# 'Per_90_Minutes_npxG+xAG'
# Also our new 'Age_Clean'

# Let's define these columns explicitly
cols_to_convert_to_numeric = [
    'Rk', 'Born', 'Playing_Time_MP', 'Playing_Time_Starts', 'Playing_Time_Min', 
    'Playing_Time_90s', 'Performance_Gls', 'Performance_Ast', 'Performance_G+A', 
    'Performance_G_PK', 'Performance_PK', 'Performance_PKatt', 'Performance_CrdY', 
    'Performance_CrdR', 'Expected_xG', 'Expected_npxG', 'Expected_xAG', 
    'Expected_npxG+xAG', 'Progression_PrgC', 'Progression_PrgP', 'Progression_PrgR',
    'Per_90_Minutes_Gls', 'Per_90_Minutes_Ast', 'Per_90_Minutes_G+A', 
    'Per_90_Minutes_G_PK', 'Per_90_Minutes_G+A_PK', 'Per_90_Minutes_xG', 
    'Per_90_Minutes_xAG', 'Per_90_Minutes_xG+xAG', 'Per_90_Minutes_npxG', 
    'Per_90_Minutes_npxG+xAG', 'Age_Clean' # Add our cleaned Age column
]

# Convert these columns to numeric, coercing errors to NaN
for col in cols_to_convert_to_numeric:
    if col in df.columns: # Check if column exists before trying to convert
        df[col] = pd.to_numeric(df[col], errors='coerce')
    else:
        print(f"Warning: Column '{col}' not found in DataFrame for numeric conversion.")

print("\nData types after attempting numeric conversion:")
df.info()

# Check for NaNs introduced by 'coerce' in a few key numeric columns
print("\nNaN counts in some key numeric columns after conversion:")
key_numeric_cols_check = ['Age_Clean', 'Playing_Time_Min', 'Performance_Gls', 'Expected_xG']
for col in key_numeric_cols_check:
    if col in df.columns:
        print(f"NaNs in {col}: {df[col].isnull().sum()}")
# Out:
# Data types after attempting numeric conversion:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rk                       569 non-null    int64
#  1   Player                   569 non-null    object
#  2   Nation                   566 non-null    object
#  3   Pos                      569 non-null    object
#  4   Squad                    569 non-null    object
#  5   Age                      566 non-null    object
#  6   Born                     566 non-null    float64
#  7   Playing_Time_MP          569 non-null    int64
#  8   Playing_Time_Starts      569 non-null    int64
#  9   Playing_Time_Min         569 non-null    int64
#  10  Playing_Time_90s         569 non-null    float64
#  11  Performance_Gls          569 non-null    int64
#  12  Performance_Ast          569 non-null    int64
#  13  Performance_G+A          569 non-null    int64
#  14  Performance_G_PK         569 non-null    int64
#  15  Performance_PK           569 non-null    int64
#  16  Performance_PKatt        569 non-null    int64
#  17  Performance_CrdY         569 non-null    int64
#  18  Performance_CrdR         569 non-null    int64
#  19  Expected_xG              569 non-null    float64
#  20  Expected_npxG            569 non-null    float64
#  21  Expected_xAG             569 non-null    float64
#  22  Expected_npxG+xAG        569 non-null    float64
#  23  Progression_PrgC         569 non-null    int64
#  24  Progression_PrgP         569 non-null    int64
#  25  Progression_PrgR         569 non-null    int64
#  26  Per_90_Minutes_Gls       569 non-null    float64
#  27  Per_90_Minutes_Ast       569 non-null    float64
#  28  Per_90_Minutes_G+A       569 non-null    float64
#  29  Per_90_Minutes_G_PK      569 non-null    float64
#  30  Per_90_Minutes_G+A_PK    569 non-null    float64
#  31  Per_90_Minutes_xG        569 non-null    float64
#  32  Per_90_Minutes_xAG       569 non-null    float64
#  33  Per_90_Minutes_xG+xAG    569 non-null    float64
#  34  Per_90_Minutes_npxG      569 non-null    float64
#  35  Per_90_Minutes_npxG+xAG  569 non-null    float64
#  36  Matches                  569 non-null    object
#  37  Age_Clean                566 non-null    float64
# dtypes: float64(17), int64(15), object(6)
# memory usage: 169.0+ KB
#
# NaN counts in some key numeric columns after conversion:
# NaNs in Age_Clean: 3
# NaNs in Playing_Time_Min: 0
# NaNs in Performance_Gls: 0
# NaNs in Expected_xG: 0

# %%
# Drop the original 'Age' column as we have 'Age_Clean'
if 'Age' in df.columns:
    df.drop('Age', axis=1, inplace=True)
    print("Dropped original 'Age' column.")

# Drop the 'Matches' column as it's redundant
if 'Matches' in df.columns:
    df.drop('Matches', axis=1, inplace=True)
    print("Dropped 'Matches' column.")

# Rename 'Age_Clean' to 'Age' for simplicity
if 'Age_Clean' in df.columns:
    df.rename(columns={'Age_Clean': 'Age'}, inplace=True)
    print("Renamed 'Age_Clean' to 'Age'.")

print("\nDataFrame info after dropping columns and renaming 'Age_Clean':")
df.info()

# Let's look at the rows with NaN Age/Born
print("\nRows with missing 'Age' or 'Born':")
missing_age_born_rows = df[df['Age'].isnull() | df['Born'].isnull()]
print(missing_age_born_rows[['Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born']])

# Decision on NaNs in 'Age' and 'Born':
# For 'Age' and 'Born', having 3 missing values out of ~570 players is very minor.
# Options:
# 1. Drop these 3 rows: If age/birth year is critical for all analysis.
# 2. Fill with a placeholder (e.g., mean, median, or a special value like 0 or -1): If we want to keep the players for other stats.
#    Mean/median imputation for age/birth year can be problematic as it introduces artificial data.
# 3. Leave as NaN: Many pandas operations and plotting libraries can handle NaNs gracefully (e.g., by ignoring them).

# For now, let's leave them as NaN. Most analyses will handle this correctly.
# If a specific analysis *requires* no NaNs in Age/Born, we can address it then.

# What about other NaNs?
# We saw 'Nation' has 3 NaNs (566 non-null out of 569 initially). These are likely the same 3 rows.
# We'll leave 'Nation' NaNs as is for now as well.

# Let's check for any other columns that might have all NaNs (unlikely now, but good check)
all_nan_cols = df.columns[df.isnull().all()].tolist()
if all_nan_cols:
    print(f"\nWarning: Columns with all NaN values: {all_nan_cols}. Consider dropping them.")
else:
    print("\nNo columns found with all NaN values.")


print("\nFinal check of first 5 rows with cleaned data structure:")
print(df.head())
# Out:
# Dropped original 'Age' column.
# Dropped 'Matches' column.
# Renamed 'Age_Clean' to 'Age'.
#
# DataFrame info after dropping columns and renaming 'Age_Clean':
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 36 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rk                       569 non-null    int64
#  1   Player                   569 non-null    object
#  2   Nation                   566 non-null    object
#  3   Pos                      569 non-null    object
#  4   Squad                    569 non-null    object
#  5   Born                     566 non-null    float64
#  6   Playing_Time_MP          569 non-null    int64
#  7   Playing_Time_Starts      569 non-null    int64
#  8   Playing_Time_Min         569 non-null    int64
#  9   Playing_Time_90s         569 non-null    float64
#  10  Performance_Gls          569 non-null    int64
#  11  Performance_Ast          569 non-null    int64
#  12  Performance_G+A          569 non-null    int64
#  13  Performance_G_PK         569 non-null    int64
#  14  Performance_PK           569 non-null    int64
#  15  Performance_PKatt        569 non-null    int64
#  16  Performance_CrdY         569 non-null    int64
#  17  Performance_CrdR         569 non-null    int64
#  18  Expected_xG              569 non-null    float64
#  19  Expected_npxG            569 non-null    float64
#  20  Expected_xAG             569 non-null    float64
#  21  Expected_npxG+xAG        569 non-null    float64
#  22  Progression_PrgC         569 non-null    int64
#  23  Progression_PrgP         569 non-null    int64
#  24  Progression_PrgR         569 non-null    int64
#  25  Per_90_Minutes_Gls       569 non-null    float64
#  26  Per_90_Minutes_Ast       569 non-null    float64
#  27  Per_90_Minutes_G+A       569 non-null    float64
#  28  Per_90_Minutes_G_PK      569 non-null    float64
#  29  Per_90_Minutes_G+A_PK    569 non-null    float64
#  30  Per_90_Minutes_xG        569 non-null    float64
#  31  Per_90_Minutes_xAG       569 non-null    float64
#  32  Per_90_Minutes_xG+xAG    569 non-null    float64
#  33  Per_90_Minutes_npxG      569 non-null    float64
#  34  Per_90_Minutes_npxG+xAG  569 non-null    float64
#  35  Age                      566 non-null    float64
# dtypes: float64(17), int64(15), object(4)
# memory usage: 160.2+ KB
#
# Rows with missing 'Age' or 'Born':
#            Player Nation    Pos           Squad  Age  Born
# 169    Jake Evans    NaN     FW  Leicester City  NaN   NaN
# 322   Mateus Mane    NaN     MF          Wolves  NaN   NaN
# 354  Jeremy Monga    NaN  FW,MF  Leicester City  NaN   NaN
#
# No columns found with all NaN values.
#
# Final check of first 5 rows with cleaned data structure:
#    Rk             Player   Nation    Pos        Squad    Born  \
# 0   1         Max Aarons  eng ENG     DF  Bournemouth  2000.0
# 1   2  Joshua Acheampong  eng ENG     DF      Chelsea  2006.0
# 2   3        Tyler Adams   us USA     MF  Bournemouth  1999.0
# 3   4   Tosin Adarabioyo  eng ENG     DF      Chelsea  1997.0
# 4   5      Simon Adingra   ci CIV  FW,MF     Brighton  2002.0
#
#    Playing_Time_MP  Playing_Time_Starts  Playing_Time_Min  Playing_Time_90s  \
# 0                3                    1                86               1.0
# 1                4                    2               170               1.9
# 2               26                   19              1785              19.8
# 3               20                   13              1229              13.7
# 4               27                   10               988              11.0
#
#    ...  Per_90_Minutes_Ast  Per_90_Minutes_G+A  Per_90_Minutes_G_PK  \
# 0  ...                0.00                0.00                 0.00
# 1  ...                0.00                0.00                 0.00
# 2  ...                0.15                0.15                 0.00
# 3  ...                0.07                0.15                 0.07
# 4  ...                0.18                0.36                 0.18
#
#    Per_90_Minutes_G+A_PK  Per_90_Minutes_xG  Per_90_Minutes_xAG  \
# 0                   0.00               0.00                0.00
# 1                   0.00               0.12                0.00
# 2                   0.15               0.08                0.05
# 3                   0.15               0.07                0.02
# 4                   0.36               0.20                0.21
#
#    Per_90_Minutes_xG+xAG  Per_90_Minutes_npxG  Per_90_Minutes_npxG+xAG   Age
# 0                   0.00                 0.00                     0.00  25.0
# 1                   0.12                 0.12                     0.12  19.0
# 2                   0.13                 0.08                     0.13  26.0
# 3                   0.08                 0.07                     0.08  27.0
# 4                   0.42                 0.20                     0.42  23.0
#
# [5 rows x 36 columns]

# %%
# Save the cleaned DataFrame to a new CSV file
cleaned_csv_path = 'fbref_2024_2025_pl_standard_stats_cleaned.csv'
df.to_csv(cleaned_csv_path, index=False)

print(f"Cleaned player stats DataFrame saved to {cleaned_csv_path}")
print(f"Shape of cleaned DataFrame: {df.shape}")
print("First 5 rows of the final cleaned DataFrame:")
print(df.head())
# Out:
# Cleaned player stats DataFrame saved to fbref_2024_2025_pl_standard_stats_cleaned.csv
# Shape of cleaned DataFrame: (569, 36)
# First 5 rows of the final cleaned DataFrame:
#    Rk             Player   Nation    Pos        Squad    Born  \
# 0   1         Max Aarons  eng ENG     DF  Bournemouth  2000.0
# 1   2  Joshua Acheampong  eng ENG     DF      Chelsea  2006.0
# 2   3        Tyler Adams   us USA     MF  Bournemouth  1999.0
# 3   4   Tosin Adarabioyo  eng ENG     DF      Chelsea  1997.0
# 4   5      Simon Adingra   ci CIV  FW,MF     Brighton  2002.0
#
#    Playing_Time_MP  Playing_Time_Starts  Playing_Time_Min  Playing_Time_90s  \
# 0                3                    1                86               1.0
# 1                4                    2               170               1.9
# 2               26                   19              1785              19.8
# 3               20                   13              1229              13.7
# 4               27                   10               988              11.0
#
#    ...  Per_90_Minutes_Ast  Per_90_Minutes_G+A  Per_90_Minutes_G_PK  \
# 0  ...                0.00                0.00                 0.00
# 1  ...                0.00                0.00                 0.00
# 2  ...                0.15                0.15                 0.00
# 3  ...                0.07                0.15                 0.07
# 4  ...                0.18                0.36                 0.18
#
#    Per_90_Minutes_G+A_PK  Per_90_Minutes_xG  Per_90_Minutes_xAG  \
# 0                   0.00               0.00                0.00
# 1                   0.00               0.12                0.00
# 2                   0.15               0.08                0.05
# 3                   0.15               0.07                0.02
# 4                   0.36               0.20                0.21
#
#    Per_90_Minutes_xG+xAG  Per_90_Minutes_npxG  Per_90_Minutes_npxG+xAG   Age
# 0                   0.00                 0.00                     0.00  25.0
# 1                   0.12                 0.12                     0.12  19.0
# 2                   0.13                 0.08                     0.13  26.0
# 3                   0.08                 0.07                     0.08  27.0
# 4                   0.42                 0.20                     0.42  23.0
#
# [5 rows x 36 columns]
